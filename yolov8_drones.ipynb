# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="cGRApSd8JXkclTu0gqD9")
project = rf.workspace("colleage-7thf7").project("drone-dataset-pw8lv")
dataset = project.version(2).download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 5.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.9 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=a0d4f5847458e1cd6feedbc85efbf333b425979ee485e04458b76468debf7c0a
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.5/609.5 kB 9.3 MB/s eta 0:00:00
# ...

# %%
import ultralytics

# !yolo task=detect mode=train model=yolov8m.pt data=/content/drone-dataset-2/data.yaml epochs=70 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 140MB/s]
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="cGRApSd8JXkclTu0gqD9")
project = rf.workspace("colleage-7thf7").project("drone-dataset-pw8lv")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.6 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=2b57d52f0d57f57cce8789a62012f9b1d2caf93e4945900b154feb0c9e8c2e06
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
# ...

# %%
# !pip install ultralytics

import ultralytics

# %%
# !yolo task=detect mode=predict model=/content/yolov8m.pt conf=0.25 source=/content/Drone-image-1096x620.jpg
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients
#
# image 1/1 /content/Drone-image-1096x620.jpg: 384x640 1 airplane, 1111.9ms
# Speed: 18.7ms preprocess, 1111.9ms inference, 30.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="cGRApSd8JXkclTu0gqD9")
project = rf.workspace("vasu").project("drone-dataset-bdlsg")
dataset = project.version(1).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Drone-Dataset-1 in yolov5pytorch:: 100%|██████████| 2206/2206 [00:00<00:00, 3156.42it/s]

# %%
# !yolo task=detect mode=train model=yolov8m.pt imgsz=640 data=/content/Drone-Dataset-1/data.yaml epochs=70 name=yolov8m_drones
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt imgsz=640 data=/content/Drone-Dataset-1/data.yaml epochs=70 name=yolov8s_drones
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt imgsz=640 data=/content/Drone-Dataset-1/data.yaml epochs=70 name=yolov8l_drones
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image, display
from IPython import display
Image(filename=f'/content/runs/detect/yolov8m_drones3/results.png',width=600)

# %%
from IPython.display import Image, display
from IPython import display
Image(filename=f'/content/runs/detect/yolov8n_drones/results.png',width=600)

# %%
from IPython.display import Image, display
from IPython import display
Image(filename=f'/content/runs/detect/yolov8s_drones/results.png',width=600)

# %%
from IPython.display import Image, display
from IPython import display
Image(filename=f'/content/runs/detect/yolov8l_drones/results.png',width=600)

# %%
# !pip install ultralytics

import ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.3/614.3 kB 6.5 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/3700000000001_024310.mp4'
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 72.9MB/s]
# Ultralytics YOLOv8.0.172 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# video 1/1 (1/2552) /content/3700000000001_024310.mp4: 384x640 (no detections), 177.9ms
# video 1/1 (2/2552) /content/3700000000001_024310.mp4: 384x640 1 car, 12.4ms
# video 1/1 (3/2552) /content/3700000000001_024310.mp4: 384x640 1 car, 11.3ms
# video 1/1 (4/2552) /content/3700000000001_024310.mp4: 384x640 1 car, 11.3ms
# video 1/1 (5/2552) /content/3700000000001_024310.mp4: 384x640 1 car, 15.0ms
# video 1/1 (6/2552) /content/3700000000001_024310.mp4: 384x640 1 car, 11.3ms
# video 1/1 (7/2552) /content/3700000000001_024310.mp4: 384x640 1 car, 11.5ms
# video 1/1 (8/2552) /content/3700000000001_024310.mp4: 384x640 1 car, 12.5ms
# video 1/1 (9/2552) /content/3700000000001_024310.mp4: 384x640 1 car, 11.3ms
# video 1/1 (10/2552) /content/3700000000001_024310.mp4: 384x640 1 car, 12.3ms
# ...

# %%
# !rm "content/result_compressed.mp4"
# Out:
# rm: cannot remove 'content/result_compressed.mp4': No such file or directory

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict/3700000000001_024310.avi'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
